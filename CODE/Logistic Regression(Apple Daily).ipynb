# %%
# %cd "/content/drive/MyDrive/Semantic Web Mining/"
# Out:
# /content/drive/MyDrive/Semantic Web Mining

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import numpy as np
from helper import remove_stopwords,Word2Vec,Lemmatizer
from sklearn.metrics import classification_report,accuracy_score
from gensim.models import Word2Vec
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import pickle
from sklearn.model_selection import KFold

# %%
df=pd.read_csv("/content/drive/Shareddrives/Semantic Web Mining Stuff/apple_news_daily_summarized_spacy.csv")
#df=df.dropna()

# %%
df1=df.dropna()
df1=df1.reset_index(drop=True)

# %%
df1
# Out:
#                                                     text  label
# 0      At 11:20 a.m. ET the Dow Jones Industrial Aver...      0
# 1      https://www.businessinsider.com/coolest-apple-...      1
# 2      exxon mobil going down 67-64 great buy and sel...      1
# 3      Data as of Jan. 29; *Three-year returns are an...      1
# 4      Citigroup increased their price target on shar...      0
# ...                                                  ...    ...
# 64582  TESLA TSLA.O - L'accélération de la cadence de...      0
# 64583  China slashes tariffs for Asian countries as U...      0
# 64584  "We advocate especially for Broadcom, which wh...      1
# 64585  Cash & Liquid Investments S&P 2018 Forecast Ra...      1
# 64586  Groundbreaking for the $10 billion Foxconn com...      0
#
# [64587 rows x 2 columns]

# %%
from sklearn.model_selection import KFold
vectorizer=CountVectorizer(ngram_range=(2,2), stop_words= ['is','to','my','a','an','the'])
new_dat=vectorizer.fit_transform(df1['text'])

# %%
with open('Newvectorizer(Apple Daily,2g).pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

# %%
kfold=KFold(4,random_state=None,shuffle=True)
#model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',max_iter=300)
scores=[]
X=new_dat
y=df1['label']
for train, test in kfold.split(new_dat):
  X_train,X_test,y_train,y_test=X[train],X[test],y[train],y[test]
  model4=LogisticRegression(penalty='l2',class_weight={0: 0.55, 1: 0.45},solver='lbfgs',max_iter=25)
  model4.fit(X_train,y_train)
  ypred=model4.predict(X_test)
  print(classification_report(y_test,ypred))
  scores.append(model4.score(X_test,y_test))
print(scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72      7778
#            1       0.74      0.73      0.74      8369
#
#     accuracy                           0.73     16147
#    macro avg       0.73      0.73      0.73     16147
# weighted avg       0.73      0.73      0.73     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      7920
#            1       0.73      0.74      0.73      8227
#
#     accuracy                           0.73     16147
#    macro avg       0.73      0.73      0.73     16147
# weighted avg       0.73      0.73      0.73     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.72      7795
#            1       0.73      0.74      0.74      8352
#
#     accuracy                           0.73     16147
#    macro avg       0.73      0.73      0.73     16147
# weighted avg       0.73      0.73      0.73     16147
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72      7798
#            1       0.74      0.73      0.74      8348
#
#     accuracy                           0.73     16146
#    macro avg       0.73      0.73      0.73     16146
# weighted avg       0.73      0.73      0.73     16146
#
# [0.7275035610330093, 0.726512664891311, 0.7265745959001673, 0.7297782732565341]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
scores
# Out:
# [0.7275035610330093, 0.726512664891311, 0.7265745959001673, 0.7297782732565341]

# %%
X_train,X_test,ytrain,ytest=train_test_split(new_dat,df1['label'],test_size=0.4,shuffle=True)
model2=LogisticRegression(penalty='l2',class_weight={0: 0.55, 1: 0.45},solver='lbfgs',max_iter=25)

# %%
model2.fit(X_train,ytrain)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight={0: 0.55, 1: 0.45}, max_iter=25)

# %%
ypred=model2.predict(X_test)
print(accuracy_score(ypred,ytest))
# Out:
# 0.7114379717437584

# %%
new=vectorizer.transform(['Apple Services reaches new all time high'])

# %%
model2.predict_proba(new)
# Out:
# array([[0.46104397, 0.53895603]])

# %%
with open('NewLogisticRegression(72.01%,Apple(daily),2g).pkl', 'wb') as f:
    pickle.dump(model2, f)

# %%
kfold=KFold(4,random_state=None,shuffle=True)
#model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',max_iter=300)
scores=[]
X=new_dat
y=df1['label']
for train, test in kfold.split(df1):
  X_train,X_test,y_train,y_test=X[train],X[test],y[train],y[test]
  model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',max_iter=300)
  model.fit(X_train,y_train)
  ypred=model.predict(X_test)
  print(classification_report(y_test,ypred))
  scores.append(model.score(X_test,y_test))
print(scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74      7731
#            1       0.76      0.79      0.78      8416
#
#     accuracy                           0.76     16147
#    macro avg       0.76      0.76      0.76     16147
# weighted avg       0.76      0.76      0.76     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75      7898
#            1       0.75      0.80      0.77      8249
#
#     accuracy                           0.76     16147
#    macro avg       0.76      0.76      0.76     16147
# weighted avg       0.76      0.76      0.76     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74      7814
#            1       0.75      0.79      0.77      8333
#
#     accuracy                           0.76     16147
#    macro avg       0.76      0.76      0.76     16147
# weighted avg       0.76      0.76      0.76     16147
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.75      7848
#            1       0.75      0.80      0.77      8298
#
#     accuracy                           0.76     16146
#    macro avg       0.76      0.76      0.76     16146
# weighted avg       0.76      0.76      0.76     16146
#
# [0.7606985817798972, 0.7612559608596025, 0.7586548584876448, 0.7601263470828689]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
np.mean(scores)
# Out:
# 0.7601839370525033

# %%
kfold=KFold(4,random_state=None,shuffle=True)
model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',max_iter=300)
scores=[]
X=new_dat
y=df1['label']
for train, test in kfold.split(df1):
  X_train,X_test,y_train,y_test=X[train],X[test],y[train],y[test]
  model.fit(X_train,y_train)
  ypred=model.predict(X_test)
  print(classification_report(y_test,ypred))
  scores.append(model.score(X_test,y_test))
print(scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.57      0.41      0.48      8704
#            1       0.48      0.64      0.55      7443
#
#     accuracy                           0.52     16147
#    macro avg       0.53      0.53      0.51     16147
# weighted avg       0.53      0.52      0.51     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.45      0.60      0.51      6611
#            1       0.64      0.49      0.55      9536
#
#     accuracy                           0.53     16147
#    macro avg       0.54      0.54      0.53     16147
# weighted avg       0.56      0.53      0.54     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50      8292
#            1       0.53      0.65      0.58      7855
#
#     accuracy                           0.54     16147
#    macro avg       0.55      0.55      0.54     16147
# weighted avg       0.55      0.54      0.54     16147
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.52      0.46      0.49      7684
#            1       0.56      0.61      0.58      8462
#
#     accuracy                           0.54     16146
#    macro avg       0.54      0.54      0.53     16146
# weighted avg       0.54      0.54      0.54     16146
#
# [0.5158853037715985, 0.5344026754195826, 0.5439400507834272, 0.5394524959742351]

# %%
with open('LogisticRegression(76.01%,Apple(daily),3g).pkl', 'wb') as f:
    pickle.dump(model, f)
