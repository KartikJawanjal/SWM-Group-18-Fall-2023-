# %%
# %cd "/content/drive/MyDrive/Semantic Web Mining/"
# Out:
# /content/drive/MyDrive/Semantic Web Mining

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import numpy as np
from helper import remove_stopwords,Word2Vec,Lemmatizer
from sklearn.metrics import classification_report,accuracy_score
from gensim.models import Word2Vec
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
df=pd.read_csv("/content/drive/Shareddrives/Semantic Web Mining Stuff/amazon_news_hourly_summarized_spacy.csv")
#df=df.dropna()

# %%
df1=df.dropna()
df1=df1.reset_index(drop=True)

# %%
df1
# Out:
#                                                     text  label
# 0      stocks to buy > 3 reasons why google stock is ...      1
# 1      why the faangs are crucial to a 2019 market ra...      1
# 2      that was despite the company's long-establishe...      0
# 3      in economic news, adp (nasdaq:adp) nonfarm emp...      0
# 4      investing.com - the dow fell more than 500 poi...      0
# ...                                                  ...    ...
# 20127  tech stocks post strong earnings several large...      1
# 20128  published: apr 29, 2018 2:21 p.m. et share‘tru...      1
# 20129  未来新的一周(2018年4月30日-2018年5月6日)，全球投资者将迎来五一国际劳动节，国...      1
# 20130  not to mention, the swedish-based company, whi...      0
# 20131  on monday, october 19 the stock rating was ini...      1
#
# [20132 rows x 2 columns]

# %%
from sklearn.model_selection import KFold
vectorizer=CountVectorizer(ngram_range=(2,2), stop_words= ['is','to','my','a','an','the'])
new_dat=vectorizer.fit_transform(df1['text'])

# %%
with open('Newvectorizer(Amazon Hourly).pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

# %%
kfold=KFold(4,random_state=None,shuffle=True)
#model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',verbose=True,max_iter=300)
scores=[]
X=new_dat
y=df1['label']
for train, test in kfold.split(df1):
  X_train,X_test,y_train,y_test=X[train],X[test],y[train],y[test]
  model=LogisticRegression(penalty='l2',class_weight={0: 0.85, 1: 0.15},solver='lbfgs',verbose=True,max_iter=25)
  model.fit(X_train,y_train)
  ypred=model.predict(X_test)
  print(classification_report(y_test,ypred))
  scores.append(model.score(X_test,y_test))
print(scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.56      0.68      0.61      2054
#            1       0.74      0.63      0.68      2979
#
#     accuracy                           0.65      5033
#    macro avg       0.65      0.65      0.65      5033
# weighted avg       0.67      0.65      0.65      5033
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.55      0.68      0.61      2056
#            1       0.74      0.61      0.67      2977
#
#     accuracy                           0.64      5033
#    macro avg       0.64      0.65      0.64      5033
# weighted avg       0.66      0.64      0.64      5033
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.59      0.69      0.64      2137
#            1       0.74      0.65      0.69      2896
#
#     accuracy                           0.67      5033
#    macro avg       0.67      0.67      0.66      5033
# weighted avg       0.68      0.67      0.67      5033
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.68      0.61      2061
#            1       0.74      0.62      0.68      2972
#
#     accuracy                           0.65      5033
#    macro avg       0.65      0.65      0.64      5033
# weighted avg       0.66      0.65      0.65      5033
#
# [0.6495132127955494, 0.6419630439101928, 0.6666004371150407, 0.6473276375918935]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
scores
# Out:
# [0.6495132127955494,
#  0.6419630439101928,
#  0.6666004371150407,
#  0.6473276375918935]

# %%
X_train,X_test,ytrain,ytest=train_test_split(new_dat,df1['label'],test_size=0.4,shuffle=True)
model2=LogisticRegression(penalty='l2',class_weight={0: 0.85, 1: 0.15},solver='lbfgs',max_iter=25)

# %%
model2.fit(X_train,ytrain)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight={0: 0.85, 1: 0.15}, max_iter=25)

# %%
ypred=model2.predict(X_test)
print(accuracy_score(ypred,ytest))
# Out:
# 0.6415000620886626

# %%
new=vectorizer.transform(['Amazon Services reaches new all time high'])

# %%
model2.predict_proba(new)
# Out:
# array([[0.48439472, 0.51560528]])

# %%
with open('NewLogisticRegression(64.15%,Amazon(Hourly),2g).pkl', 'wb') as f:
    pickle.dump(model2, f)

# %%
kfold=KFold(4,random_state=None,shuffle=True)
#model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',verbose=True,max_iter=300)
scores=[]
X=new_dat
y=df1['label']
for train, test in kfold.split(df1):
  X_train,X_test,y_train,y_test=X[train],X[test],y[train],y[test]
  model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',verbose=True,max_iter=300)
  model.fit(X_train,y_train)
  ypred=model.predict(X_test)
  print(classification_report(y_test,ypred))
  scores.append(model.score(X_test,y_test))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.51      0.58      2092
#            1       0.70      0.82      0.76      2941
#
#     accuracy                           0.69      5033
#    macro avg       0.69      0.67      0.67      5033
# weighted avg       0.69      0.69      0.68      5033
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.57      2072
#            1       0.70      0.81      0.75      2961
#
#     accuracy                           0.69      5033
#    macro avg       0.68      0.66      0.66      5033
# weighted avg       0.68      0.69      0.68      5033
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.52      0.57      2066
#            1       0.70      0.80      0.75      2967
#
#     accuracy                           0.69      5033
#    macro avg       0.67      0.66      0.66      5033
# weighted avg       0.68      0.69      0.68      5033
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.51      0.57      2078
#            1       0.70      0.81      0.75      2955
#
#     accuracy                           0.69      5033
#    macro avg       0.68      0.66      0.66      5033
# weighted avg       0.68      0.69      0.68      5033
#
# [0.6916352076296444, 0.6856745479833102, 0.6850784820186767, 0.685873236638188]

# %%
np.mean(scores)
# Out:
# 0.6870653685674548

# %%
with open('LogisticRegression(68.70%,Amazon(Hourly),3g).pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',max_iter=300)
accuracies=cross_val_score(estimator=model,X=new_dat,y=df1['label'],cv=4)

# %%
accuracies
# Out:
# array([0.58831711, 0.55275184, 0.53228691, 0.5533479 ])

# %%
kfold=KFold(4,random_state=None,shuffle=True)
#model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',verbose=True,max_iter=300)
scores=[]
X=new_dat
y=df1['label']
for train, test in kfold.split(df1):
  X_train,X_test,y_train,y_test=X[train],X[test],y[train],y[test]
  model=LogisticRegression(penalty='l2',class_weight='balanced',solver='lbfgs',verbose=True,max_iter=300)
  model.fit(X_train,y_train)
  ypred=model.predict(X_test)
  print(classification_report(y_test,ypred))
  scores.append(model.score(X_test,y_test))
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.11      0.17      1809
#            1       0.65      0.92      0.76      3224
#
#     accuracy                           0.63      5033
#    macro avg       0.54      0.51      0.47      5033
# weighted avg       0.57      0.63      0.55      5033
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.11      0.17      1711
#            1       0.67      0.93      0.78      3322
#
#     accuracy                           0.65      5033
#    macro avg       0.55      0.52      0.47      5033
# weighted avg       0.59      0.65      0.57      5033
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.11      0.18      2394
#            1       0.53      0.91      0.67      2639
#
#     accuracy                           0.53      5033
#    macro avg       0.53      0.51      0.43      5033
# weighted avg       0.53      0.53      0.44      5033
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.10      0.17      2394
#            1       0.53      0.92      0.67      2639
#
#     accuracy                           0.53      5033
#    macro avg       0.53      0.51      0.42      5033
# weighted avg       0.53      0.53      0.43      5033
#
# [0.6284522153785019, 0.647923703556527, 0.5308960858334989, 0.5295052652493543]

# %%
scores
# Out:
# [0.6284522153785019, 0.647923703556527, 0.5308960858334989, 0.5295052652493543]

# %%
np.mean(scores)
# Out:
# 0.5841943175044705

# %%
with open('LogisticRegression(58.41%,Amazon,6g).pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# train['Label'].apply(int)
# test['Label'].apply(int)
# Out:
# 1        0
# 2        1
# 3        0
# 4        0
# 5        0
#         ..
# 40452    1
# 40453    1
# 40454    0
# 40455    1
# 71244    1
# Name: Label, Length: 9084, dtype: int64

# %%
model=LogisticRegression(penalty='l2',class_weight=None,solver='lbfgs',verbose=True)
model.fit(train_dat,train['Label'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(verbose=True)

# %%
ytrain=model.predict(train_dat)
ytest1=model1.predict(test_dat)

# %%
print('train accuracy: ',accuracy_score(ytrain,train['Label']))
# Out:
# train accuracy:  0.9870438551521648

# %%
print('test accuracy: ', accuracy_score(ytest,test['Label']))
print(classification_report(ytest,test['Label']))
# Out:
# test accuracy:  0.5227873183619551
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.47      0.51      4728
#          1.0       0.50      0.58      0.54      4356
#
#     accuracy                           0.52      9084
#    macro avg       0.53      0.53      0.52      9084
# weighted avg       0.53      0.52      0.52      9084
